# %% [markdown]
# # Sum Square Difference
#
# The sum of the squares of the first ten natural numbers is
#
# ```12 + 22 + ... + 102 = 385```
#
# The square of the sum of the first ten natural numbers is,
#
# ```(1 + 2 + ... + 10)2 = 552 = 3025```
#
# Hence the difference between the sum of the squares of the first ten natural numbers and the square of the sum is 3025 − 385 = 2640.
#
# Find the difference between the sum of the squares of the first one hundred natural numbers and the square of the sum.

# %%
def sum_of_squares(x):
    sum=0
    #calculate sum of squares
    
    return sum

# %%
def square_of_sum(x):
    sum = 0
    #calculate square of sum
    
    return sum

# %%
def diff(x,y):
    

    return x-y

# %%
#main program
num=10

diff(sum_of_squares(num), square_of_sum(num))
# Out:
# 0

# %% [markdown]
# # Highly divisible triangular number
#
# The sequence of triangle numbers is generated by adding the natural numbers. So the 7th triangle number would be 1 + 2 + 3 + 4 + 5 + 6 + 7 = 28. The first ten terms would be:
#
# ```1, 3, 6, 10, 15, 21, 28, 36, 45, 55, ...```
#
# Let us list the factors of the first seven triangle numbers:
#
# ```
#  1: 1
#  3: 1,3
#  6: 1,2,3,6
# 10: 1,2,5,10
# 15: 1,3,5,15
# 21: 1,3,7,21
# 28: 1,2,4,7,14,28
# ```
#
# We can see that 28 is the first triangle number to have over five divisors.
#
# What is the value of the first triangle number to have over five hundred divisors?

# %%
def tri_numbers(n):
    
    nth_tri_num = 0
    
    #work out the nth triangle number
    
    return nth_tri_num

# %%
def num_divisors(x):
    num_div = 0
    
    #work out how many divisors x has
    
    return num_div

# %%
#test program
x=17
triangle_number = tri_numbers(x) # this should work out the 17th triangle number
num_div = num_divisors(triangle_number)
print("the {}th trianlge number is {} and it has {} divisors".format(x,triangle_number,num_div))
# Out:
# the 17th trianlge number is 0 and it has 0 divisors

# %%
#now answer the questi
